# %% [markdown]
# <h1>Data Preprocessing Notebook for Covid Diet Project</h1>

# %%
#Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler

#Performing Principal Component Analysis on Fat Supply, Protien Supply, kcal intake, and kg supply.
#Given that our data is so high dimensional, we wish to see what features are the most imoortant among all features.

protein_dataset = pd.read_csv('data/Protein_Supply_Quantity_Data.csv')
kcal_dataset = pd.read_csv('data/Food_Supply_kcal_Data.csv')
kg_dataset = pd.read_csv('data/Food_Supply_Quantity_kg_Data.csv')
fat_dataset = pd.read_csv('data/Fat_Supply_Quantity_Data.csv')
#Note, each column before obesity & undernourished sums up to 100%

# %%
#prepare the dataframes for merging

#drop the covid columns that are the same in every dataframe, except for one dataframe
#remove Unit (all except Population) column, as it is totally useless
kcal_dataset=kcal_dataset.drop(['Obesity', 'Undernourished','Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)'],axis=1)
kg_dataset=kg_dataset.drop(['Obesity', 'Undernourished','Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)'],axis=1)
fat_dataset=fat_dataset.drop(['Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population', 'Unit (all except Population)'],axis=1)
protein_dataset=protein_dataset.drop(['Unit (all except Population)'],axis=1)

# %%
#append an identifier at the end of each dataframe row to show where it came from
for (columnName, columnData) in kcal_dataset.iteritems(): 
    if(columnName!="Country"):
        kcal_dataset.rename(columns={columnName: columnName+"_kcal"}, inplace=True)
for (columnName, columnData) in fat_dataset.iteritems():
    if(columnName!="Country"):
        fat_dataset.rename(columns={columnName: columnName+"_f"}, inplace=True)
for (columnName, columnData) in kg_dataset.iteritems(): 
    if(columnName!="Country"):
        kg_dataset.rename(columns={columnName: columnName+"_kg"}, inplace=True)
keepColumns = ['Country','Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population']
for (columnName, columnData) in protein_dataset.iteritems(): 
    rename=True
    for keepName in keepColumns:
        if(columnName==keepName):
            rename=False
    if(rename):
        protein_dataset.rename(columns={columnName: columnName+"_p"}, inplace=True)

# %%
#finally, merge the dataframes
merged_df = kcal_dataset.merge(fat_dataset, left_on='Country', right_on='Country')
merged_df = merged_df.merge(protein_dataset, left_on='Country', right_on='Country')
merged_df = merged_df.merge(kg_dataset, left_on='Country', right_on='Country')

# %%
#taking a look at the undernourished column, we can see that there is a strange value: <2.5
merged_df['Undernourished'].unique()
# Out:
# array(['29.8', '6.2', '3.9', '25', nan, '4.6', '4.3', '<2.5', '14.7',
#        '7.5', '10.1', '17.1', '26.4', '3.6', '20', '12.6', '16.4', '9.9',
#        '59.6', '37.5', '2.7', '8.5', '4.8', '40.3', '19', '5.6', '18.9',
#        '9.5', '7.9', '4.5', '9', '2.9', '20.6', '3.7', '4.2', '10.5',
#        '10.2', '5.5', '15.2', '16.5', '28', '8.1', '49.3', '12.9', '14.5',
#        '8.3', '4.9', '29', '8', '12.2', '29.4', '47.8', '2.8', '7.1',
#        '11', '13.1', '37.2', '44.4', '17.5', '2.5', '10.3', '6.3', '10.4',
#        '6.5', '13.4', '3.4', '27.9', '10.6', '27.3', '8.7', '17', '3.2',
#        '6.8', '20.3', '10', '10.7', '9.7', '13.3', '36.8', '5.7', '7',
#        '11.3', '25.6', '8.9', '20.1', '3.5', '7.8', '24.9', '16.1', '5.4',
#        '41', '2.6', '30.7', '7.2', '21.2', '9.3', '38.9', '46.7', '51.3'],
#       dtype=object)

# %%
#Just replace it with 2.5
merged_df["Undernourished"] = protein_dataset["Undernourished"].replace('<2.5','2.5')

# %%
#We can see that unit has been fixed, but undernourished is not a float
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 0 to 169
# Data columns (total 100 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        170 non-null    object
#  1   Alcoholic Beverages_kcal       170 non-null    float64
#  2   Animal Products_kcal           170 non-null    float64
#  3   Animal fats_kcal               170 non-null    float64
#  4   Aquatic Products, Other_kcal   170 non-null    float64
#  5   Cereals - Excluding Beer_kcal  170 non-null    float64
#  6   Eggs_kcal                      170 non-null    float64
#  7   Fish, Seafood_kcal             170 non-null    float64
#  8   Fruits - Excluding Wine_kcal   170 non-null    float64
#  9   Meat_kcal                      170 non-null    float64
#  10  Milk - Excluding Butter_kcal   170 non-null    float64
#  11  Miscellaneous_kcal             170 non-null    float64
#  12  Offals_kcal                    170 non-null    float64
#  13  Oilcrops_kcal                  170 non-null    float64
#  14  Pulses_kcal                    170 non-null    float64
#  15  Spices_kcal                    170 non-null    float64
#  16  Starchy Roots_kcal             170 non-null    float64
#  17  Stimulants_kcal                170 non-null    float64
#  18  Sugar Crops_kcal               170 non-null    float64
#  19  Sugar & Sweeteners_kcal        170 non-null    float64
#  20  Treenuts_kcal                  170 non-null    float64
#  21  Vegetal Products_kcal          170 non-null    float64
#  22  Vegetable Oils_kcal            170 non-null    float64
#  23  Vegetables_kcal                170 non-null    float64
#  24  Alcoholic Beverages_f          170 non-null    float64
#  25  Animal Products_f              170 non-null    float64
#  26  Animal fats_f                  170 non-null    float64
#  27  Aquatic Products, Other_f      170 non-null    float64
#  28  Cereals - Excluding Beer_f     170 non-null    float64
#  29  Eggs_f                         170 non-null    float64
#  30  Fish, Seafood_f                170 non-null    float64
#  31  Fruits - Excluding Wine_f      170 non-null    float64
#  32  Meat_f                         170 non-null    float64
#  33  Miscellaneous_f                170 non-null    float64
#  34  Milk - Excluding Butter_f      170 non-null    float64
#  35  Offals_f                       170 non-null    float64
#  36  Oilcrops_f                     170 non-null    float64
#  37  Pulses_f                       170 non-null    float64
#  38  Spices_f                       170 non-null    float64
#  39  Starchy Roots_f                170 non-null    float64
#  40  Stimulants_f                   170 non-null    float64
#  41  Sugar Crops_f                  170 non-null    float64
#  42  Sugar & Sweeteners_f           170 non-null    float64
#  43  Treenuts_f                     170 non-null    float64
#  44  Vegetal Products_f             170 non-null    float64
#  45  Vegetable Oils_f               170 non-null    float64
#  46  Vegetables_f                   170 non-null    float64
#  47  Alcoholic Beverages_p          170 non-null    float64
#  48  Animal Products_p              170 non-null    float64
#  49  Animal fats_p                  170 non-null    float64
#  50  Aquatic Products, Other_p      170 non-null    float64
#  51  Cereals - Excluding Beer_p     170 non-null    float64
#  52  Eggs_p                         170 non-null    float64
#  53  Fish, Seafood_p                170 non-null    float64
#  54  Fruits - Excluding Wine_p      170 non-null    float64
#  55  Meat_p                         170 non-null    float64
#  56  Milk - Excluding Butter_p      170 non-null    float64
#  57  Offals_p                       170 non-null    float64
#  58  Oilcrops_p                     170 non-null    float64
#  59  Pulses_p                       170 non-null    float64
#  60  Spices_p                       170 non-null    float64
#  61  Starchy Roots_p                170 non-null    float64
#  62  Stimulants_p                   170 non-null    float64
#  63  Sugar Crops_p                  170 non-null    float64
#  64  Sugar & Sweeteners_p           170 non-null    float64
#  65  Treenuts_p                     170 non-null    float64
#  66  Vegetal Products_p             170 non-null    float64
#  67  Vegetable Oils_p               170 non-null    float64
#  68  Vegetables_p                   170 non-null    float64
#  69  Miscellaneous_p                170 non-null    float64
#  70  Obesity                        167 non-null    float64
#  71  Undernourished                 163 non-null    object
#  72  Confirmed                      164 non-null    float64
#  73  Deaths                         164 non-null    float64
#  74  Recovered                      164 non-null    float64
#  75  Active                         162 non-null    float64
#  76  Population                     170 non-null    float64
#  77  Alcoholic Beverages_kg         170 non-null    float64
#  78  Animal fats_kg                 170 non-null    float64
#  79  Animal Products_kg             170 non-null    float64
#  80  Aquatic Products, Other_kg     170 non-null    float64
#  81  Cereals - Excluding Beer_kg    170 non-null    float64
#  82  Eggs_kg                        170 non-null    float64
#  83  Fish, Seafood_kg               170 non-null    float64
#  84  Fruits - Excluding Wine_kg     170 non-null    float64
#  85  Meat_kg                        170 non-null    float64
#  86  Milk - Excluding Butter_kg     170 non-null    float64
#  87  Miscellaneous_kg               170 non-null    float64
#  88  Offals_kg                      170 non-null    float64
#  89  Oilcrops_kg                    170 non-null    float64
#  90  Pulses_kg                      170 non-null    float64
#  91  Spices_kg                      170 non-null    float64
#  92  Starchy Roots_kg               170 non-null    float64
#  93  Stimulants_kg                  170 non-null    float64
#  94  Sugar & Sweeteners_kg          170 non-null    float64
#  95  Sugar Crops_kg                 170 non-null    float64
#  96  Treenuts_kg                    170 non-null    float64
#  97  Vegetable Oils_kg              170 non-null    float64
#  98  Vegetables_kg                  170 non-null    float64
#  99  Vegetal Products_kg            170 non-null    float64
# dtypes: float64(98), object(2)
# memory usage: 134.1+ KB

# %%
merged_df["Undernourished"] = pd.to_numeric((merged_df["Undernourished"]), downcast="float")
#It is now fixed
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 0 to 169
# Data columns (total 100 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        170 non-null    object
#  1   Alcoholic Beverages_kcal       170 non-null    float64
#  2   Animal Products_kcal           170 non-null    float64
#  3   Animal fats_kcal               170 non-null    float64
#  4   Aquatic Products, Other_kcal   170 non-null    float64
#  5   Cereals - Excluding Beer_kcal  170 non-null    float64
#  6   Eggs_kcal                      170 non-null    float64
#  7   Fish, Seafood_kcal             170 non-null    float64
#  8   Fruits - Excluding Wine_kcal   170 non-null    float64
#  9   Meat_kcal                      170 non-null    float64
#  10  Milk - Excluding Butter_kcal   170 non-null    float64
#  11  Miscellaneous_kcal             170 non-null    float64
#  12  Offals_kcal                    170 non-null    float64
#  13  Oilcrops_kcal                  170 non-null    float64
#  14  Pulses_kcal                    170 non-null    float64
#  15  Spices_kcal                    170 non-null    float64
#  16  Starchy Roots_kcal             170 non-null    float64
#  17  Stimulants_kcal                170 non-null    float64
#  18  Sugar Crops_kcal               170 non-null    float64
#  19  Sugar & Sweeteners_kcal        170 non-null    float64
#  20  Treenuts_kcal                  170 non-null    float64
#  21  Vegetal Products_kcal          170 non-null    float64
#  22  Vegetable Oils_kcal            170 non-null    float64
#  23  Vegetables_kcal                170 non-null    float64
#  24  Alcoholic Beverages_f          170 non-null    float64
#  25  Animal Products_f              170 non-null    float64
#  26  Animal fats_f                  170 non-null    float64
#  27  Aquatic Products, Other_f      170 non-null    float64
#  28  Cereals - Excluding Beer_f     170 non-null    float64
#  29  Eggs_f                         170 non-null    float64
#  30  Fish, Seafood_f                170 non-null    float64
#  31  Fruits - Excluding Wine_f      170 non-null    float64
#  32  Meat_f                         170 non-null    float64
#  33  Miscellaneous_f                170 non-null    float64
#  34  Milk - Excluding Butter_f      170 non-null    float64
#  35  Offals_f                       170 non-null    float64
#  36  Oilcrops_f                     170 non-null    float64
#  37  Pulses_f                       170 non-null    float64
#  38  Spices_f                       170 non-null    float64
#  39  Starchy Roots_f                170 non-null    float64
#  40  Stimulants_f                   170 non-null    float64
#  41  Sugar Crops_f                  170 non-null    float64
#  42  Sugar & Sweeteners_f           170 non-null    float64
#  43  Treenuts_f                     170 non-null    float64
#  44  Vegetal Products_f             170 non-null    float64
#  45  Vegetable Oils_f               170 non-null    float64
#  46  Vegetables_f                   170 non-null    float64
#  47  Alcoholic Beverages_p          170 non-null    float64
#  48  Animal Products_p              170 non-null    float64
#  49  Animal fats_p                  170 non-null    float64
#  50  Aquatic Products, Other_p      170 non-null    float64
#  51  Cereals - Excluding Beer_p     170 non-null    float64
#  52  Eggs_p                         170 non-null    float64
#  53  Fish, Seafood_p                170 non-null    float64
#  54  Fruits - Excluding Wine_p      170 non-null    float64
#  55  Meat_p                         170 non-null    float64
#  56  Milk - Excluding Butter_p      170 non-null    float64
#  57  Offals_p                       170 non-null    float64
#  58  Oilcrops_p                     170 non-null    float64
#  59  Pulses_p                       170 non-null    float64
#  60  Spices_p                       170 non-null    float64
#  61  Starchy Roots_p                170 non-null    float64
#  62  Stimulants_p                   170 non-null    float64
#  63  Sugar Crops_p                  170 non-null    float64
#  64  Sugar & Sweeteners_p           170 non-null    float64
#  65  Treenuts_p                     170 non-null    float64
#  66  Vegetal Products_p             170 non-null    float64
#  67  Vegetable Oils_p               170 non-null    float64
#  68  Vegetables_p                   170 non-null    float64
#  69  Miscellaneous_p                170 non-null    float64
#  70  Obesity                        167 non-null    float64
#  71  Undernourished                 163 non-null    float32
#  72  Confirmed                      164 non-null    float64
#  73  Deaths                         164 non-null    float64
#  74  Recovered                      164 non-null    float64
#  75  Active                         162 non-null    float64
#  76  Population                     170 non-null    float64
#  77  Alcoholic Beverages_kg         170 non-null    float64
#  78  Animal fats_kg                 170 non-null    float64
#  79  Animal Products_kg             170 non-null    float64
#  80  Aquatic Products, Other_kg     170 non-null    float64
#  81  Cereals - Excluding Beer_kg    170 non-null    float64
#  82  Eggs_kg                        170 non-null    float64
#  83  Fish, Seafood_kg               170 non-null    float64
#  84  Fruits - Excluding Wine_kg     170 non-null    float64
#  85  Meat_kg                        170 non-null    float64
#  86  Milk - Excluding Butter_kg     170 non-null    float64
#  87  Miscellaneous_kg               170 non-null    float64
#  88  Offals_kg                      170 non-null    float64
#  89  Oilcrops_kg                    170 non-null    float64
#  90  Pulses_kg                      170 non-null    float64
#  91  Spices_kg                      170 non-null    float64
#  92  Starchy Roots_kg               170 non-null    float64
#  93  Stimulants_kg                  170 non-null    float64
#  94  Sugar & Sweeteners_kg          170 non-null    float64
#  95  Sugar Crops_kg                 170 non-null    float64
#  96  Treenuts_kg                    170 non-null    float64
#  97  Vegetable Oils_kg              170 non-null    float64
#  98  Vegetables_kg                  170 non-null    float64
#  99  Vegetal Products_kg            170 non-null    float64
# dtypes: float32(1), float64(98), object(1)
# memory usage: 133.5+ KB

# %%
#Investigate missing values
missing_vals = merged_df.isnull().sum().sort_values(ascending = False)
missing_vals.head(7)
# Out:
# Active            8
# Undernourished    7
# Deaths            6
# Recovered         6
# Confirmed         6
# Obesity           3
# Sugar Crops_f     0
# dtype: int64

# %%
'''
As we can see, several countries have missing values for certain columns. 
'''
missing_df = merged_df[merged_df.isna().any(axis=1)]
missing_df
# Out:
#                    Country  Alcoholic Beverages_kcal  Animal Products_kcal  \
# 4      Antigua and Barbuda                    2.3041               15.3672
# 10                 Bahamas                    2.9145               14.7930
# 26                  Canada                    1.5748               12.6986
# 29                   Chile                    1.5942               12.3547
# 52        French Polynesia                    1.4879               15.0676
# 59                 Grenada                    1.9979               12.2581
# 80                Kiribati                    0.1145                5.9555
# 81            Korea, North                    1.4282                3.1273
# 105                Myanmar                    0.1296               10.8663
# 109          New Caledonia                    1.9087               13.3430
# 124    Republic of Moldova                    2.0672               12.2990
# 128  Saint Kitts and Nevis                    1.6696               14.2715
# 129            Saint Lucia                    2.5564               14.6429
# 147                Taiwan*                    1.2767               10.9525
# 148             Tajikistan                    0.1427                5.1831
# 155           Turkmenistan                    0.2263               13.1267
#
#      Animal fats_kcal  Aquatic Products, Other_kcal  \
# 4              1.5429                           0.0
# 10             1.4205                           0.0
# 26             3.9656                           0.0
# 29             1.3783                           0.0
# 52             1.8129                           0.0
# 59             0.7284                           0.0
# 80             0.2291                           0.0
# 81             0.0000                           0.0
# 105            0.8145                           0.0
# 109            1.4361                           0.0
# 124            1.7958                           0.0
# 128            1.6498                           0.0
# 129            1.0526                           0.0
# 147            1.0415                           0.0
# 148            0.0000                           0.0
# 155            1.7409                           0.0
#
#      Cereals - Excluding Beer_kcal  Eggs_kcal  Fish, Seafood_kcal  \
# 4                          13.7215     0.2057              1.7280
# 10                         10.7274     0.6613              1.2491
# 26                         13.0279     0.7731              0.5297
# 29                         19.5782     0.6310              0.3985
# 52                         15.8885     0.4960              1.6419
# 59                         13.7565     0.7284              1.1446
# 80                         16.9993     0.1309              2.6014
# 81                         29.9926     0.4432              0.4186
# 105                        23.4358     0.3887              2.0548
# 109                        15.9607     0.6362              0.8544
# 124                        21.3823     0.6264              0.4803
# 128                        13.3969     0.3180              0.9541
# 129                        15.3571     0.2444              1.2218
# 147                        15.4208     0.9071              0.7559
# 148                        27.4132     0.2140              0.0238
# 155                        27.4025     0.4701              0.1045
#
#      Fruits - Excluding Wine_kcal  Meat_kcal  ...  Pulses_kg  Spices_kg  \
# 4                          3.6824     7.0356  ...     0.1840     0.1524
# 10                         4.4575     8.1803  ...     0.0504     0.0884
# 26                         1.8182     4.7960  ...     0.6304     0.0574
# 29                         1.2786     7.4228  ...     0.2677     0.0133
# 52                         1.0433     8.1409  ...     0.1452     0.0111
# 59                         3.5588     5.7648  ...     0.6417     0.3171
# 80                         1.8815     2.6832  ...     0.0032     0.0064
# 81                         1.6991     2.0438  ...     1.1000     0.0000
# 105                        1.3514     6.3680  ...     1.2806     0.2170
# 109                        1.6906     6.5261  ...     0.1275     0.0488
# 124                        1.1485     3.6542  ...     0.0642     0.0068
# 128                        2.2262     7.5929  ...     0.5422     0.0901
# 129                        2.0113     8.9286  ...     0.5663     0.1780
# 147                        2.0830     6.9881  ...     0.2077     0.1023
# 148                        1.5216     2.3776  ...     0.2486     0.0305
# 155                        1.3231     6.4415  ...     0.1032     0.0015
#
#      Starchy Roots_kg  Stimulants_kg  Sugar & Sweeteners_kg  Sugar Crops_kg  \
# 4              1.4522         0.1564                 3.8749          0.0000
# 10             1.0547         0.1556                 6.2151          0.0000
# 26             3.4940         0.4053                 5.0237          0.0000
# 29             4.7183         0.1353                 3.5582          0.0000
# 52             3.5436         0.1260                 2.8715          0.6809
# 59             2.2222         0.1104                 5.4480          0.0000
# 80             7.1830         0.0311                 4.1373          0.0000
# 81             6.2438         0.0142                 0.3694          0.0000
# 105            1.4514         0.2298                 2.8592          0.0000
# 109            2.5648         0.1745                 3.1901          0.0000
# 124            3.9066         0.0830                 2.6632          0.0000
# 128            2.7150         0.0749                 6.4623          0.0000
# 129            2.6427         0.0602                 3.7043          0.0000
# 147            0.8565         0.1374                 2.3455          0.2826
# 148            2.9278         0.0555                 1.6607          0.0000
# 155            2.3000         0.0945                 0.6746          0.0000
#
#      Treenuts_kg  Vegetable Oils_kg  Vegetables_kg  Vegetal Products_kg
# 4         0.0253             0.8102         5.4495              33.3233
# 10        0.0495             0.5110         7.7649              38.5229
# 26        0.1439             1.3441         5.4961              33.9551
# 29        0.1190             0.5435         5.3092              34.9584
# 52        0.0405             0.9675         4.0992              35.6559
# 59        0.0143             0.9959         3.6085              37.8648
# 80        0.1951             0.4419         4.1389              41.1042
# 81        0.0426             0.7783        12.8082              46.6046
# 105       0.2913             0.6322         7.0725              36.4807
# 109       0.0376             1.3157         5.5941              38.2208
# 124       0.0180             0.8250         6.4285              33.4640
# 128       0.0673             1.3850         4.2090              35.9677
# 129       0.0575             0.6103         4.1169              35.0964
# 147       0.4185             1.8271         9.1938              37.8684
# 148       0.0582             0.8419        19.2995              42.7642
# 155       0.0283             0.5655        10.4014              33.9389
#
# [16 rows x 100 columns]

# %%
missing_df = protein_dataset[protein_dataset.isna().any(axis=1)]
missing_df
# Out:
#                    Country  Alcoholic Beverages_p  Animal Products_p  \
# 4      Antigua and Barbuda                 0.1535            33.1901
# 10                 Bahamas                 0.0325            34.1684
# 26                  Canada                 0.3458            25.1828
# 29                   Chile                 0.2314            25.6899
# 52        French Polynesia                 0.3778            32.9981
# 59                 Grenada                 0.1204            30.3273
# 80                Kiribati                 0.0338            24.9594
# 81            Korea, North                 0.0287            10.0832
# 105                Myanmar                 0.0161            23.9286
# 109          New Caledonia                 0.3262            29.1790
# 124    Republic of Moldova                 0.3236            24.3154
# 128  Saint Kitts and Nevis                 0.3183            32.0169
# 129            Saint Lucia                 0.3355            30.1926
# 147                Taiwan*                 0.2391            24.7580
# 148             Tajikistan                 0.0090            12.1401
# 155           Turkmenistan                 0.0000            21.5563
#
#      Animal fats_p  Aquatic Products, Other_p  Cereals - Excluding Beer_p  \
# 4           0.1289                     0.0000                     10.5108
# 10          0.0895                     0.0000                      7.8081
# 26          0.6868                     0.0049                     12.9249
# 29          0.1016                     0.0000                     17.7775
# 52          0.2042                     0.0153                     10.7050
# 59          0.0567                     0.0000                     12.2414
# 80          0.0473                     0.0000                     15.3680
# 81          0.0000                     0.0000                     23.9070
# 105         0.0911                     0.0000                     16.0006
# 109         0.1873                     0.0181                     13.6531
# 124         0.2052                     0.0000                     20.4719
# 128         0.1104                     0.0000                     10.9516
# 129         0.0578                     0.0000                     12.7653
# 147         0.0350                     0.0175                     12.9738
# 148         0.0000                     0.0000                     28.2246
# 155         0.0485                     0.0000                     24.3242
#
#      Eggs_p  Fish, Seafood_p  Fruits - Excluding Wine_p   Meat_p  ...  \
# 4    0.4850           8.2146                     1.2586  16.0670  ...
# 10   1.6755           5.7340                     1.8788  20.4311  ...
# 26   2.0553           2.8755                     0.6868  13.7253  ...
# 29   1.6141           2.0374                     0.4966  16.5077  ...
# 52   1.1741           7.0448                     0.3931  18.8677  ...
# 59   1.8631           5.9719                     1.4452  15.3939  ...
# 80   0.4058          16.1052                     0.9131   7.6502  ...
# 81   1.3872           2.9561                     0.6218   5.0990  ...
# 105  0.8517           8.7797                     0.4018  10.2743  ...
# 109  1.6915           3.9207                     0.6585  15.3749  ...
# 124  1.8388           2.5570                     0.5130   9.9676  ...
# 128  0.7795           5.1770                     0.8444  19.6622  ...
# 129  0.5784           5.4370                     0.7577  18.0172  ...
# 147  2.4082           4.5073                     0.7813  14.7930  ...
# 148  0.6499           0.0903                     0.5777   5.5601  ...
# 155  1.1201           0.4685                     0.4254  12.3586  ...
#
#      Vegetable Oils_p  Vegetables_p  Miscellaneous_p  Obesity  Undernourished  \
# 4              0.0430        1.6024           0.2947     19.1             NaN
# 10             0.0325        2.6759           1.1305     32.1             NaN
# 26             0.0840        1.5909           0.2915     31.3            <2.5
# 29             0.0169        1.4222           0.0734     28.8             2.7
# 52             0.0153        1.2558           1.1129      NaN             4.2
# 59             0.0283        0.7793           0.3684     20.2             NaN
# 80             0.0000        1.3731           0.1420     45.6             2.7
# 81             0.0000        4.6398           0.0287      7.1            47.8
# 105            0.0000        1.8213           0.0804      5.7            10.6
# 109            0.0362        1.7640           1.1841      NaN             7.1
# 124            0.0158        1.8073           0.2052     20.1             NaN
# 128            0.0585        0.8574           0.5781     23.1             NaN
# 129            0.0463        0.9312           0.4107     19.8             NaN
# 147            0.0058        2.8571           0.0991      NaN             3.5
# 148            0.0090        5.0546           0.1083     12.6             NaN
# 155            0.0162        1.8255           0.0915     17.5             5.4
#
#      Confirmed    Deaths  Recovered    Active  Population
# 4     0.293878  0.007143   0.190816  0.095918     98000.0
# 10    2.100763  0.044784   1.735115  0.320865    393000.0
# 26    2.109961  0.054203   1.909848       NaN  38190000.0
# 29    3.842229  0.097047   3.626194       NaN  19470000.0
# 52         NaN       NaN        NaN       NaN    280000.0
# 59    0.130973  0.000885   0.129204  0.000885    113000.0
# 80         NaN       NaN        NaN       NaN    125000.0
# 81         NaN       NaN        NaN       NaN  25779000.0
# 105        NaN       NaN        NaN       NaN  54704000.0
# 109        NaN       NaN        NaN       NaN    295000.0
# 124   4.646195  0.099859   4.333692  0.212645   3535000.0
# 128   0.074074  0.000000   0.066667  0.007407     54000.0
# 129   0.996154  0.009890   0.480769  0.505495    182000.0
# 147   0.003914  0.000038   0.003571  0.000305  23610000.0
# 148   0.141139  0.000955   0.140185  0.000000   9429000.0
# 155        NaN       NaN        NaN       NaN   6031000.0
#
# [16 rows x 31 columns]

# %%
#Using john hopkins covid data, fill in the active cases as a percentage of population
merged_df['Active'] = np.where(merged_df['Country'] == 'Chile', 123835/merged_df.Population, merged_df.Active)
merged_df['Active'] = np.where(merged_df['Country'] == 'Canada', 89998/merged_df.Population, merged_df.Active)

# %%
'''
Unfortunately, we cannot estimate the covid data, because that's going to be related to our predictive outcomes.
Any estimation would just not be realistic.
For this reason, we drop the following countries:
'''
index_names = merged_df[ (merged_df['Country'] == 'Turkmenistan') | (merged_df['Country'] == 'French Polynesia') | (merged_df['Country'] == 'Korea, North') | (merged_df['Country'] == 'Kiribati') | (merged_df['Country'] == 'Myanmar') | (merged_df['Country'] == 'New Caledonia')].index
merged_df.drop(index_names, inplace = True)

# %%
merged_na_df = merged_df[merged_df.isna().any(axis=1)]
merged_na_df['Undernourished']
# Out:
# 4      NaN
# 10     NaN
# 59     NaN
# 124    NaN
# 128    NaN
# 129    NaN
# 147    3.5
# 148    NaN
# Name: Undernourished, dtype: float32

# %%
#estimate the missing values using the knn inputer
from sklearn.impute import KNNImputer
#In order to use the knn inputer we need to have no text fields, so i'm storing the country names somewhere else
copy_df = merged_df.copy(deep=True)
copy_df.drop(copy_df.columns.difference(['Country','Population']), 1, inplace=True)
#drop the country frame to use the inputer
merged_df = merged_df.drop(['Country'],axis=1)
imputer = KNNImputer(n_neighbors=5) 
merged_df = pd.DataFrame(imputer.fit_transform(merged_df), columns=merged_df.columns)

# %%
#put the country names back where they belong
merged_df = merged_df.merge(copy_df, left_on='Population', right_on='Population')

# %%
merged_df.to_csv(r'data/merged_df.csv', index = False)

# %%
kcal_cols = [col for col in merged_df.columns if col.endswith('kcal')] + ['Country','Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population']
data_kcal = merged_df[kcal_cols]
data_kcal.to_csv(r'data/data_clean/kcal_data_clean.csv', index = False)

fat_cols = [col for col in merged_df.columns if col.endswith('f')] + ['Country','Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population']
data_fat = merged_df[fat_cols]
data_fat.to_csv(r'data/data_clean/fat_data_clean.csv', index = False)

protein_cols = [col for col in merged_df.columns if col.endswith('p')] + ['Country','Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population']
data_protein = merged_df[protein_cols]
data_protein.to_csv(r'data/data_clean/protein_data_clean.csv', index = False)

kg_cols = [col for col in merged_df.columns if col.endswith('kg')] + ['Country','Obesity', 'Undernourished', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'Population']
data_kg = merged_df[kg_cols]
data_kg.to_csv(r'data/data_clean/kg_data_clean.csv', index = False)
